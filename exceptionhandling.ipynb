# %%
try:
    num1=float(input("enter the first number"))
    num2=float(input("enter the second number"))
    
    result=num1 / num2
    
except ValueError:
    print("ERROR!!:please enter the numeric values,")
except ZeroDivisionError:
     print("ERROR!!:Division by zero  is not allowed,")
else:
    print("Result = ",result)
        
finally:
    print("program exicution completed.")
# Out:
# enter the first numberten
# ERROR!!:please enter the numeric values,
# program exicution completed.
