# %%
#read a file line by line and store it into a list
with open("sample.text","r")as file:
    lines=file.readlines()
print("lines in file:")
print(lines)
file.close()
# Out:
# lines in file:
# ['Nefla\n', 'MCA 1st year student\n', 'kmct college\n']

# %%
#copy odd lines of one file to another
file1=input("enter the source file:")
file2=input("enter the destination file:")

f1=open(file1,"r")
f2=open(file2,"w")
i=0
for line in f1.readlines():
    i=i+1
    if i%2==0:
        continue
    f2.write(line)
f1.close()
f2.close()

print("Odd lines copied successfully from",file1,"to",file2)
# Out:
# enter the source file:source.txt
# enter the destination file:destination.txt
# Odd lines copied successfully from source.txt to destination.txt

# %%
#read each rw
import csv
fname=input("Emter the csv file name:")
f1=open(fname,"r")
reader=csv.reader(f1)
for row in reader:
    print(row)
f1.close()
# Out:
# Emter the csv file name:student.csv
# ['NAME', 'AGE', 'MARK']
# ['nefla', '21', '85']
# ['saniya', '22', '93']
# ['shaikha', '20', '88']

# %%
import csv
fname=input("EnterThe Csv file name:")
with open(fname,"r")as f1:
    reader=csv.DictReader(f1)
    print("\n Department Detais:")
    print(".......")
    for row in reader:
        print("DeptId:",row['DeptId'],"\tDeptName:",row['DeptName'])
# Out:
# EnterThe Csv file name:department.csv
#
#  Department Detais:
# .......
# DeptId: 101 	DeptName: Computer Science
# DeptId: 102 	DeptName: Electronics
# DeptId: 103 	DeptName: Commerce
# DeptId: 104 	DeptName: Mathematics

# %%
import csv
data = [
{"Name": "Nefla", "Age": 21, "Marks": 85},
{"Name": "Ayisha", "Age": 22, "Marks": 78},
{"Name": "Ridhan", "Age": 20, "Marks": 91}
]

with open("students_dict.csv", "w", newline='') as file:
        fieldnames = ["Name", "Age", "Marks"]
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(data)
print("Dictionary data written successfully!")

with open("students_dict.csv", "r") as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)
# Out:
# Dictionary data written successfully!
# ['Name', 'Age', 'Marks']
# ['Nefla', '21', '85']
# ['Ayisha', '22', '78']
# ['Ridhan', '20', '91']
